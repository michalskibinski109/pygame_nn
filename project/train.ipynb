# %%
from tensorflow.keras.layers import (
    Dense,
    Conv2D,
    Flatten,
    Input
)
from tensorflow.keras import Model
import pandas as pd
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import cv2

# %%
path = Path('data')
X_train = np.load(path/'X_train.npy')
y_train = np.load(path/'y_train.npy')
X_test = np.load(path/'X_test.npy')
test_images = np.load(path/'X_test.npy') 
y_test = np.load(path/'y_test.npy')
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((366, 32, 32, 3), (366, 5), (92, 32, 32, 3), (92, 5))

# %%
test_images.shape
# Out:
# (92, 32, 32, 3)

# %%
def filter_grey(X:np.ndarray):
    new_x = []
    for i in range(len(X)):
        img = X[i]
        # np array to cv2 imag
        grey = (109, 108, 111)
        light_grey = (146, 145, 149)
        
        mask = cv2.inRange(img,grey, light_grey)
        result = cv2.bitwise_and(img, img, mask=mask)
        # grey scale
        result = cv2.cvtColor(result, cv2.COLOR_BGR2GRAY)
        result = result / 255
        new_x.append(result)
    return np.array(new_x)

X_train = filter_grey(X_train)
X_test = filter_grey(X_test)

# %%
EPOCHS = 100
BATCH_SIZE = 32
IMG_SIZE = X_train.shape[1]
X_test.shape
# Out:
# (92, 32, 32)

# %%
fig, ax = plt.subplots(2, 3, figsize=(10, 8))
images = np.random.choice(X_train.shape[0], 6)
for i in range(2):
    for j in range(3):
        rect = y_train[images[i * 3 + j]][1:]
        label = y_train[images[i * 3 + j]][0]
        print(rect)
        x, y, w, h = rect
        ax[i, j].add_patch(
            plt.Rectangle(
                (x * IMG_SIZE, y * IMG_SIZE),
                w * IMG_SIZE,
                h * IMG_SIZE,
                fill=False,
                edgecolor="red",
                lw=3,
            )
        )
        ax[i,j].set_title(f"Class: {label}")
        ax[i, j].imshow(X_train[images[i * 3 + j]], cmap="gray")

plt.show()
# Out:
# [0.37890625 0.0703125  0.22265625 0.4453125 ]
# [0.109375   0.12890625 0.22265625 0.4453125 ]
# [0. 0. 0. 0.]
# [0. 0. 0. 0.]
# [0.08203125 0.1640625  0.22265625 0.4453125 ]
# [0.19140625 0.1640625  0.22265625 0.4453125 ]

# %%
def build_model():
    # Define model layers.
    input_layer = Input(name= 'input' ,shape=(IMG_SIZE, IMG_SIZE, 1))
    first_dense = Conv2D(32, (6,6), activation='relu', name='conv1')(input_layer)
    flatten_layer = Flatten(name= 'flatten' )(first_dense)
    second_dense = Dense(units=8,activation='relu', name='relu1')(flatten_layer)
    y1_output = Dense(units=1, name='classification')(second_dense)
    y2_output = Dense(units=4,name='regression',activation='relu')(second_dense)
    model = Model(inputs=input_layer,outputs=[y1_output, y2_output])
    return model

# %%
model = build_model()
optimizer = Adam()
model.compile(optimizer=optimizer, loss={'classification': 'binary_crossentropy', 'regression': 'mse'})
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 32, 32, 1)]  0           []
#
#  conv1 (Conv2D)                 (None, 27, 27, 32)   1184        ['input[0][0]']
#
#  flatten (Flatten)              (None, 23328)        0           ['conv1[0][0]']
#
#  relu1 (Dense)                  (None, 8)            186632      ['flatten[0][0]']
#
#  classification (Dense)         (None, 1)            9           ['relu1[0][0]']
#
#  regression (Dense)             (None, 4)            36          ['relu1[0][0]']
#
# ==================================================================================================
# Total params: 187,861
# Trainable params: 187,861
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#history = model.fit(X_train, y_train[:,1:], epochs=EPOCHS, batch_size=BATCH_SIZE)
history = model.fit(X_train, {'classification': y_train[:,0], 'regression': y_train[:,1:]}, epochs=EPOCHS, batch_size=BATCH_SIZE)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0025 - classification_loss: 0.0000e+00 - regression_loss: 0.0025
# Epoch 2/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0023 - classification_loss: 0.0000e+00 - regression_loss: 0.0023
# Epoch 3/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0022 - classification_loss: 0.0000e+00 - regression_loss: 0.0022
# Epoch 4/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0021 - classification_loss: 0.0000e+00 - regression_loss: 0.0021
# Epoch 5/100
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0020 - classification_loss: 1.1003e-05 - regression_loss: 0.0020
# Epoch 6/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0019 - classification_loss: 0.0000e+00 - regression_loss: 0.0019
# Epoch 7/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0019 - classification_loss: 0.0000e+00 - regression_loss: 0.0019
# Epoch 8/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0018 - classification_loss: 0.0000e+00 - regression_loss: 0.0018
# Epoch 9/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0016 - classification_loss: 0.0000e+00 - regression_loss: 0.0016
# Epoch 10/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0015 - classification_loss: 0.0000e+00 - regression_loss: 0.0015
# Epoch 11/100
# 12/12 [==============================] - 0s 20ms/step - loss: 0.0014 - classification_loss: 3.7535e-06 - regression_loss: 0.0014
# Epoch 12/100
# 12/12 [==============================] - 0s 20ms/step - loss: 0.0014 - classification_loss: 0.0000e+00 - regression_loss: 0.0014
# Epoch 13/100
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0013 - classification_loss: 0.0000e+00 - regression_loss: 0.0013
# Epoch 14/100
# 12/12 [==============================] - 0s 20ms/step - loss: 0.0012 - classification_loss: 0.0000e+00 - regression_loss: 0.0012
# Epoch 15/100
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0011 - classification_loss: 0.0000e+00 - regression_loss: 0.0011
# Epoch 16/100
# 12/12 [==============================] - 0s 19ms/step - loss: 0.0011 - classification_loss: 0.0000e+00 - regression_loss: 0.0011
# Epoch 17/100
# 12/12 [==============================] - 0s 19ms/step - loss: 9.8865e-04 - classification_loss: 0.0000e+00 - regression_loss: 9.8865e-04
# Epoch 18/100
# 12/12 [==============================] - 0s 20ms/step - loss: 9.5586e-04 - classification_loss: 0.0000e+00 - regression_loss: 9.5586e-04
# Epoch 19/100
# 12/12 [==============================] - 0s 21ms/step - loss: 8.6882e-04 - classification_loss: 0.0000e+00 - regression_loss: 8.6882e-04
# Epoch 20/100
# 12/12 [==============================] - 0s 21ms/step - loss: 8.4540e-04 - classification_loss: 0.0000e+00 - regression_loss: 8.4540e-04
# Epoch 21/100
# 12/12 [==============================] - 0s 18ms/step - loss: 8.1210e-04 - classification_loss: 0.0000e+00 - regression_loss: 8.1210e-04
# Epoch 22/100
# 12/12 [==============================] - 0s 17ms/step - loss: 7.4863e-04 - classification_loss: 0.0000e+00 - regression_loss: 7.4863e-04
# Epoch 23/100
# 12/12 [==============================] - 0s 19ms/step - loss: 8.0783e-04 - classification_loss: 0.0000e+00 - regression_loss: 8.0783e-04
# Epoch 24/100
# 12/12 [==============================] - 0s 17ms/step - loss: 8.4370e-04 - classification_loss: 0.0000e+00 - regression_loss: 8.4370e-04
# Epoch 25/100
# 12/12 [==============================] - 0s 17ms/step - loss: 7.5673e-04 - classification_loss: 1.9475e-06 - regression_loss: 7.5478e-04
# Epoch 26/100
# 12/12 [==============================] - 0s 16ms/step - loss: 7.7820e-04 - classification_loss: 1.4743e-05 - regression_loss: 7.6346e-04
# Epoch 27/100
# 12/12 [==============================] - 0s 15ms/step - loss: 8.3263e-04 - classification_loss: 0.0000e+00 - regression_loss: 8.3263e-04
# Epoch 28/100
# 12/12 [==============================] - 0s 15ms/step - loss: 6.8367e-04 - classification_loss: 0.0000e+00 - regression_loss: 6.8367e-04
# Epoch 29/100
# 12/12 [==============================] - 0s 16ms/step - loss: 5.7664e-04 - classification_loss: 0.0000e+00 - regression_loss: 5.7664e-04
# Epoch 30/100
# 12/12 [==============================] - 0s 15ms/step - loss: 5.2684e-04 - classification_loss: 0.0000e+00 - regression_loss: 5.2684e-04
# Epoch 31/100
# 12/12 [==============================] - 0s 16ms/step - loss: 5.2249e-04 - classification_loss: 0.0000e+00 - regression_loss: 5.2249e-04
# Epoch 32/100
# 12/12 [==============================] - 0s 16ms/step - loss: 5.4487e-04 - classification_loss: 0.0000e+00 - regression_loss: 5.4487e-04
# Epoch 33/100
# 12/12 [==============================] - 0s 15ms/step - loss: 6.6920e-04 - classification_loss: 0.0000e+00 - regression_loss: 6.6920e-04
# Epoch 34/100
# 12/12 [==============================] - 0s 15ms/step - loss: 7.1206e-04 - classification_loss: 0.0000e+00 - regression_loss: 7.1206e-04
# Epoch 35/100
# 12/12 [==============================] - 0s 15ms/step - loss: 6.4523e-04 - classification_loss: 0.0000e+00 - regression_loss: 6.4523e-04
# Epoch 36/100
# 12/12 [==============================] - 0s 16ms/step - loss: 6.5444e-04 - classification_loss: 0.0000e+00 - regression_loss: 6.5444e-04
# Epoch 37/100
# 12/12 [==============================] - 0s 16ms/step - loss: 4.3079e-04 - classification_loss: 0.0000e+00 - regression_loss: 4.3079e-04
# Epoch 38/100
# 12/12 [==============================] - 0s 15ms/step - loss: 3.9185e-04 - classification_loss: 0.0000e+00 - regression_loss: 3.9185e-04
# Epoch 39/100
# 12/12 [==============================] - 0s 15ms/step - loss: 3.9282e-04 - classification_loss: 0.0000e+00 - regression_loss: 3.9282e-04
# Epoch 40/100
# 12/12 [==============================] - 0s 17ms/step - loss: 3.8899e-04 - classification_loss: 0.0000e+00 - regression_loss: 3.8899e-04
# Epoch 41/100
# 12/12 [==============================] - 0s 16ms/step - loss: 3.5029e-04 - classification_loss: 0.0000e+00 - regression_loss: 3.5029e-04
# Epoch 42/100
# 12/12 [==============================] - 0s 16ms/step - loss: 3.6912e-04 - classification_loss: 0.0000e+00 - regression_loss: 3.6912e-04
# Epoch 43/100
# 12/12 [==============================] - 0s 15ms/step - loss: 3.1162e-04 - classification_loss: 0.0000e+00 - regression_loss: 3.1162e-04
# Epoch 44/100
# 12/12 [==============================] - 0s 16ms/step - loss: 2.8425e-04 - classification_loss: 0.0000e+00 - regression_loss: 2.8425e-04
# Epoch 45/100
# 12/12 [==============================] - 0s 16ms/step - loss: 3.0637e-04 - classification_loss: 0.0000e+00 - regression_loss: 3.0637e-04
# Epoch 46/100
# 12/12 [==============================] - 0s 15ms/step - loss: 3.2226e-04 - classification_loss: 2.7133e-06 - regression_loss: 3.1955e-04
# Epoch 47/100
# 12/12 [==============================] - 0s 15ms/step - loss: 3.5326e-04 - classification_loss: 0.0000e+00 - regression_loss: 3.5326e-04
# Epoch 48/100
# 12/12 [==============================] - 0s 15ms/step - loss: 3.3648e-04 - classification_loss: 0.0000e+00 - regression_loss: 3.3648e-04
# Epoch 49/100
# 12/12 [==============================] - 0s 16ms/step - loss: 3.1639e-04 - classification_loss: 0.0000e+00 - regression_loss: 3.1639e-04
# Epoch 50/100
# 12/12 [==============================] - 0s 16ms/step - loss: 2.7497e-04 - classification_loss: 0.0000e+00 - regression_loss: 2.7497e-04
# Epoch 51/100
# 12/12 [==============================] - 0s 16ms/step - loss: 2.6177e-04 - classification_loss: 0.0000e+00 - regression_loss: 2.6177e-04
# Epoch 52/100
# 12/12 [==============================] - 0s 16ms/step - loss: 2.4616e-04 - classification_loss: 0.0000e+00 - regression_loss: 2.4616e-04
# Epoch 53/100
# 12/12 [==============================] - 0s 15ms/step - loss: 2.3432e-04 - classification_loss: 0.0000e+00 - regression_loss: 2.3432e-04
# Epoch 54/100
# 12/12 [==============================] - 0s 16ms/step - loss: 2.4489e-04 - classification_loss: 0.0000e+00 - regression_loss: 2.4489e-04
# Epoch 55/100
# 12/12 [==============================] - 0s 15ms/step - loss: 2.2076e-04 - classification_loss: 0.0000e+00 - regression_loss: 2.2076e-04
# Epoch 56/100
# 12/12 [==============================] - 0s 15ms/step - loss: 2.0251e-04 - classification_loss: 0.0000e+00 - regression_loss: 2.0251e-04
# Epoch 57/100
# 12/12 [==============================] - 0s 15ms/step - loss: 1.9016e-04 - classification_loss: 0.0000e+00 - regression_loss: 1.9016e-04
# Epoch 58/100
# 12/12 [==============================] - 0s 16ms/step - loss: 1.8793e-04 - classification_loss: 0.0000e+00 - regression_loss: 1.8793e-04
# Epoch 59/100
# 12/12 [==============================] - 0s 15ms/step - loss: 1.8299e-04 - classification_loss: 0.0000e+00 - regression_loss: 1.8299e-04
# Epoch 60/100
# 12/12 [==============================] - 0s 16ms/step - loss: 1.9364e-04 - classification_loss: 0.0000e+00 - regression_loss: 1.9364e-04
# Epoch 61/100
# 12/12 [==============================] - 0s 16ms/step - loss: 1.8936e-04 - classification_loss: 0.0000e+00 - regression_loss: 1.8936e-04
# Epoch 62/100
# 12/12 [==============================] - 0s 15ms/step - loss: 1.9185e-04 - classification_loss: 0.0000e+00 - regression_loss: 1.9185e-04
# Epoch 63/100
# 12/12 [==============================] - 0s 16ms/step - loss: 1.8739e-04 - classification_loss: 0.0000e+00 - regression_loss: 1.8739e-04
# Epoch 64/100
# 12/12 [==============================] - 0s 16ms/step - loss: 1.8858e-04 - classification_loss: 0.0000e+00 - regression_loss: 1.8858e-04
# Epoch 65/100
# 12/12 [==============================] - 0s 15ms/step - loss: 1.6954e-04 - classification_loss: 0.0000e+00 - regression_loss: 1.6954e-04
# Epoch 66/100
# 12/12 [==============================] - 0s 16ms/step - loss: 1.8477e-04 - classification_loss: 0.0000e+00 - regression_loss: 1.8477e-04
# Epoch 67/100
# 12/12 [==============================] - 0s 15ms/step - loss: 1.8261e-04 - classification_loss: 0.0000e+00 - regression_loss: 1.8261e-04
# Epoch 68/100
# 12/12 [==============================] - 0s 16ms/step - loss: 2.0927e-04 - classification_loss: 0.0000e+00 - regression_loss: 2.0927e-04
# Epoch 69/100
# 12/12 [==============================] - 0s 15ms/step - loss: 1.9443e-04 - classification_loss: 0.0000e+00 - regression_loss: 1.9443e-04
# Epoch 70/100
# 12/12 [==============================] - 0s 15ms/step - loss: 1.7458e-04 - classification_loss: 0.0000e+00 - regression_loss: 1.7458e-04
# Epoch 71/100
# 12/12 [==============================] - 0s 16ms/step - loss: 2.9304e-04 - classification_loss: 0.0000e+00 - regression_loss: 2.9304e-04
# Epoch 72/100
# 12/12 [==============================] - 0s 16ms/step - loss: 2.8137e-04 - classification_loss: 0.0000e+00 - regression_loss: 2.8137e-04
# Epoch 73/100
# 12/12 [==============================] - 0s 15ms/step - loss: 2.4689e-04 - classification_loss: 0.0000e+00 - regression_loss: 2.4689e-04
# Epoch 74/100
# 12/12 [==============================] - 0s 16ms/step - loss: 2.8580e-04 - classification_loss: 0.0000e+00 - regression_loss: 2.8580e-04
# Epoch 75/100
# 12/12 [==============================] - 0s 15ms/step - loss: 4.0233e-04 - classification_loss: 0.0000e+00 - regression_loss: 4.0233e-04
# Epoch 76/100
# 12/12 [==============================] - 0s 15ms/step - loss: 5.1085e-04 - classification_loss: 0.0000e+00 - regression_loss: 5.1085e-04
# Epoch 77/100
# 12/12 [==============================] - 0s 15ms/step - loss: 5.6447e-04 - classification_loss: 0.0000e+00 - regression_loss: 5.6447e-04
# Epoch 78/100
# 12/12 [==============================] - 0s 16ms/step - loss: 5.3697e-04 - classification_loss: 0.0000e+00 - regression_loss: 5.3697e-04
# Epoch 79/100
# 12/12 [==============================] - 0s 15ms/step - loss: 3.3761e-04 - classification_loss: 0.0000e+00 - regression_loss: 3.3761e-04
# Epoch 80/100
# 12/12 [==============================] - 0s 15ms/step - loss: 3.5116e-04 - classification_loss: 0.0000e+00 - regression_loss: 3.5116e-04
# Epoch 81/100
# 12/12 [==============================] - 0s 15ms/step - loss: 4.1364e-04 - classification_loss: 0.0000e+00 - regression_loss: 4.1364e-04
# Epoch 82/100
# 12/12 [==============================] - 0s 15ms/step - loss: 5.5968e-04 - classification_loss: 0.0000e+00 - regression_loss: 5.5968e-04
# Epoch 83/100
# 12/12 [==============================] - 0s 16ms/step - loss: 4.5552e-04 - classification_loss: 0.0000e+00 - regression_loss: 4.5552e-04
# Epoch 84/100
# 12/12 [==============================] - 0s 15ms/step - loss: 4.6699e-04 - classification_loss: 0.0000e+00 - regression_loss: 4.6699e-04
# Epoch 85/100
# 12/12 [==============================] - 0s 16ms/step - loss: 5.3027e-04 - classification_loss: 3.6254e-05 - regression_loss: 4.9402e-04
# Epoch 86/100
# 12/12 [==============================] - 0s 15ms/step - loss: 4.4749e-04 - classification_loss: 0.0000e+00 - regression_loss: 4.4749e-04
# Epoch 87/100
# 12/12 [==============================] - 0s 15ms/step - loss: 5.0452e-04 - classification_loss: 0.0000e+00 - regression_loss: 5.0452e-04
# Epoch 88/100
# 12/12 [==============================] - 0s 15ms/step - loss: 6.9282e-04 - classification_loss: 0.0000e+00 - regression_loss: 6.9282e-04
# Epoch 89/100
# 12/12 [==============================] - 0s 15ms/step - loss: 6.1516e-04 - classification_loss: 0.0000e+00 - regression_loss: 6.1516e-04
# Epoch 90/100
# 12/12 [==============================] - 0s 15ms/step - loss: 6.0343e-04 - classification_loss: 0.0000e+00 - regression_loss: 6.0343e-04
# Epoch 91/100
# 12/12 [==============================] - 0s 16ms/step - loss: 6.5085e-04 - classification_loss: 0.0000e+00 - regression_loss: 6.5085e-04
# Epoch 92/100
# 12/12 [==============================] - 0s 16ms/step - loss: 5.9960e-04 - classification_loss: 0.0000e+00 - regression_loss: 5.9960e-04
# Epoch 93/100
# 12/12 [==============================] - 0s 15ms/step - loss: 7.0066e-04 - classification_loss: 0.0000e+00 - regression_loss: 7.0066e-04
# Epoch 94/100
# 12/12 [==============================] - 0s 16ms/step - loss: 7.0838e-04 - classification_loss: 0.0000e+00 - regression_loss: 7.0838e-04
# Epoch 95/100
# 12/12 [==============================] - 0s 17ms/step - loss: 4.6363e-04 - classification_loss: 0.0000e+00 - regression_loss: 4.6363e-04
# Epoch 96/100
# 12/12 [==============================] - 0s 15ms/step - loss: 3.4059e-04 - classification_loss: 0.0000e+00 - regression_loss: 3.4059e-04
# Epoch 97/100
# 12/12 [==============================] - 0s 15ms/step - loss: 2.5455e-04 - classification_loss: 0.0000e+00 - regression_loss: 2.5455e-04
# Epoch 98/100
# 12/12 [==============================] - 0s 16ms/step - loss: 2.3016e-04 - classification_loss: 0.0000e+00 - regression_loss: 2.3016e-04
# Epoch 99/100
# 12/12 [==============================] - 0s 16ms/step - loss: 1.9459e-04 - classification_loss: 0.0000e+00 - regression_loss: 1.9459e-04
# Epoch 100/100
# 12/12 [==============================] - 0s 16ms/step - loss: 1.8519e-04 - classification_loss: 0.0000e+00 - regression_loss: 1.8519e-04

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
# Out:
# <AxesSubplot: >

# %%
model.predict(X_test[:1])[1][0]
# Out:
# 1/1 [==============================] - 0s 138ms/step
# array([0.        , 0.        , 0.01878421, 0.01437137], dtype=float32)

# %%
fig, ax = plt.subplots(2, 3, figsize=(10, 8))
imgs = np.random.choice(X_test.shape[0], 6)
for i in range(2):
    for j in range(3):
        index = np.random.randint(0, X_test.shape[0])
        rect = model.predict(X_test[index:index+1], verbose=0)[1][0]
        classification = model.predict(X_test[index:index+1], verbose=0)[0][0]
        print(rect)
        x, y, w, h = rect
        color = 'red' if classification > 0.5 else 'blue'
        ax[i, j].add_patch(
            plt.Rectangle(
                (x * IMG_SIZE, y * IMG_SIZE),
                w * IMG_SIZE,
                h * IMG_SIZE,
                fill=False,
                edgecolor=color,
                lw=3,
            )
            )
        # draw true rect 
        
        ax[i, j].imshow(test_images[index]/ 255)
plt.show()
# Out:
# [0.78772825 0.10374495 0.23017408 0.46129587]
# [0.         0.         0.00210644 0.00401763]
# [0.85629463 0.272603   0.23806392 0.47692764]
# [0.20694691 0.412415   0.25940287 0.51949066]
# [0.02198499 0.35712674 0.22669762 0.45394325]
# [0.64424354 0.04067793 0.21211222 0.4251306 ]
